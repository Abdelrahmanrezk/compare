# %%
# This is initialization for server

# %%
# !pip3 install twarc
# !pip3 install twint
# !pip3 install urllib3
# !pip3 install gensim
# !pip3 install nltk
# !pip3 install pycld2
# !pip3 install googletrans
# !pip3 install emojis
# !pip3 install emosent-py
# !pip3 install spacy_langdetect

# !pip3 install spacy
# !pip3 install sklearn
# !pip3 install python-bidi
# !pip3 install matplotlib
# !pip3 install arabic-reshaper
# !pip3 install gdown
# Out:
# ...
#      |████████████████████████████████| 59 kB 13.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 38.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 96 kB 32.3 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 78 kB 45.6 MB/s  eta 0:00:01
# ...
#   Created wheel for configobj: filename=configobj-5.0.6-py3-none-any.whl size=34546 sha256=a7677bb30cbc56b5aa991852430c0ebb4dd0b950a8db1f7f4489b114996878ae
#   Stored in directory: /root/.cache/pip/wheels/34/2a/24/a490264ae9041fd48f778ff393526572c80bb498ddecb07ea5
# Successfully built configobj
# ...
# WARNING: You are using pip version 20.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# ...
#      |████████████████████████████████| 1.3 MB 79.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 265 kB 90.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 372 kB 70.6 MB/s eta 0:00:01
# ...

# %%
# !pip install gdown

# %%
import gdown

# %%
url = "https://drive.google.com/u/3/uc?id=1e-q1CL09d3DYeGX2gL9tKmqcxZkkI98T&export=download"
output = "ourmodels.zip"
gdown.download(url, output)

# %%
url = "https://drive.google.com/u/2/uc?id=1vby7UzVk1ocIdJlWBNdi8R5dY2np_rNS&export=download"
output = "server_3.zip"
gdown.download(url, output)
